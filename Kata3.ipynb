# %% [markdown]
# # Ejercicio - Escribir declaraciones `if`, `else`, y `elif`

# %%
# Aplica el tip de práctica 1.
a = 100
b = 27
if a >= b:
    print(a)
# Out:
# 100

# %%
c = 100
d = 27
if d >= c:
    print(d)
    if d == c:
        print ("son iguales")
    else: 
        print ("No son iguales")
elif d <= c:
    print(c)
# Out:
# 100

# %%
ast = 49
if ast>=25:
    print ("Alerta de asteroide")

else:
    print ("Sin alertas")
# Out:
# Alerta de asteroide

# %%
aste = 22
if aste > 20:
    print("Asteroide arriba")
elif aste == 20:
    print("Perligro asteroide")
else:
    print("Sin novedad")
# Out:
# Asteroide arriba

# %%
vel = 25
tam = 40
if vel > 25 and tam > 25:
    print("Peligro de impacto")
elif vel >= 20:
    print("Asteroide visible")
elif tam < 25:
    print("Sin novedad")
else:
    print("Sin novedad"')
# Out:
#   Input In [8]
#     print("Sin novedad"')
#                        ^
# SyntaxError: unterminated string literal (detected at line 10)
